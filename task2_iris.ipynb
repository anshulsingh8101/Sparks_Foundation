# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = "https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/"
df_iris = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-5-747469edc34c> in <module>
#       1 url = "https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/"
# ----> 2 df_iris = pd.read_csv(url)
#
# C:\Anaconda3\envs\sparks_intern\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\Anaconda3\envs\sparks_intern\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# C:\Anaconda3\envs\sparks_intern\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1194     def read(self, nrows=None):
#    1195         nrows = _validate_integer("nrows", nrows)
# -> 1196         ret = self._engine.read(nrows)
#    1197
#    1198         # May alter columns / col_dict
#
# C:\Anaconda3\envs\sparks_intern\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2153     def read(self, nrows=None):
#    2154         try:
# -> 2155             data = self._reader.read(nrows)
#    2156         except StopIteration:
#    2157             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 284 fields in line 135, saw 427

# %%
df_iris.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style>@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>Iris.csv - Google Drive</title><meta property="og:title" content="Iris.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/view?usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    400  500  \
# 0  NaN    1
# 1  NaN    5
# 2    6    1
# 3  NaN    1
# 4  NaN  NaN
#
#   700"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.-XQluPm-Qio.R.X.O/d=0/ct=zgms/rs=AO0039toe1LhCEF66rOy6WAj8calLUw3-A"><script>_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                NaN
# 1                                                  1
# 2                                                  1
# 3                                                NaN
# 4                                                  1
#
#   docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd"              docs-shdn:0  \
# 0                    0                       1                       1]
# 1                  NaN                     NaN                        1
# 2                  NaN                     NaN                      NaN
# 3                  NaN                   [null                      NaN
# 4                  NaN                     NaN  https://docs.google.com
#
#                 docs-tfh:"" info_params:{}  \
# 0                       NaN            NaN
# 1  https://drive.google.com            NaN
# 2                        3]            NaN
# 3                       NaN            NaN
# 4                       NaN              1
#
#                                    docos-eddmh:false  ... 1.6 null.14 null.15  \
# 0                                                NaN  ... NaN     NaN     NaN
# 1                                                NaN  ... NaN     NaN     NaN
# 2                                                NaN  ... NaN     NaN     NaN
# 3  https://accounts.google.com/ServiceLogin?servi...  ... NaN     NaN     NaN
# 4                                              [null  ... NaN     NaN     NaN
#
#   AIzaSyC1eQ1xj69IdTMeii5r7brs3R90eck-m7k null.16 /drive/v2beta 0.13 0.14 1.7  \
# 0                                     NaN     NaN           NaN  NaN  NaN NaN
# 1                                     NaN     NaN           NaN  NaN  NaN NaN
# 2                                     NaN     NaN           NaN  NaN  NaN NaN
# 3                                     NaN     NaN           NaN  NaN  NaN NaN
# 4                                     NaN     NaN           NaN  NaN  NaN NaN
#
#   [0]
# 0 NaN
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
#
# [5 rows x 284 columns]
